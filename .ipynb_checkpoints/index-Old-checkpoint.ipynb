# %% [markdown]
# # CMSC320 Final Project Prototype
# ---

# %%
# Enter into terminal to update website: jupyter nbconvert --to html index.ipynb
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import selenium.webdriver as webdriver
import contextlib2
sns.set(style="darkgrid")
# %matplotlib inline
# Get list of team initials to create nested for loop for schedules
teams = ['ATL','BOS','BRK','CHI','CHO','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM','MIA','MIL',
         'MIN','NOP','NYK','OKC','ORL','PHI','PHO','POR','SAC','SAS','TOR','UTA','WAS']
defunct = ['NJN','CHA','CHH','SFW','SDR','SDC','BUF','VAN','NOK','NOH','SEA','KCK','KCO','CIN','NOJ','WSB','CAP',
           'BAL']
associated = {'BRK':['NJN'],'CHO':['CHA','CHH'],'GSW':['SFW'],'HOU':['SDR'],'LAC':['SDC','BUF'],'MEM':['VAN'],
             'NOP':['NOK','NOH'],'OKC':['SEA'],'SAC':['KCK','KCO','CIN'],'UTA':['NOJ'],'WAS':['WSB','CAP','BAL']}
mvp = ['i/iversal01', 'd/duncati01', 'd/duncati01', 'g/garneke01', 'n/nashst01', 'n/nashst01', 'n/nowitdi01', 
       'b/bryanko01', 'j/jamesle01', 'j/jamesle01', 'r/rosede01', 'j/jamesle01', 'j/jamesle01', 'd/duranke01', 
       'c/curryst01', 'c/curryst01', 'w/westbru01', 'h/hardeja01', 'a/antetgi01']
mvp_names = {'i/iversal01': 'Allen Iverson', 'd/duncati01': 'Tim Duncan', 'g/garneke01': 'Kevin Garnett',
            'n/nashst01': 'Steve Nash', 'n/nowitdi01': 'Dirk Nowitzki', 'b/bryanko01': 'Kobe Bryant',
            'j/jamesle01': 'LeBron James', 'r/rosede01': 'Derrick Rose', 'd/duranke01': 'Kevin Durant',
            'c/curryst01': 'Stephen Curry', 'w/westbru01': 'Russell Westbrook', 'h/hardeja01': 'James Harden',
            'a/antetgi01': 'Giannis Antetokounmpo'}
mvp_years = {'Allen Iverson': ['2000'], 'Tim Duncan': ['2001','2002'], 'Kevin Garnett': ['2003'], 
             'Steve Nash': ['2004', '2005'], 'Dirk Nowitzki': ['2006'], 'Kobe Bryant': ['2007'],
            'LeBron James': ['2008', '2009', '2011', '2012'], 'Derrick Rose': ['2010'], 'Kevin Durant': ['2013'],
            'Stephen Curry': ['2014', '2015'], 'Russell Westbrook': ['2016'], 'James Harden': ['2017'],
            'Giannis Antetokounmpo': ['2018']}

# %% [markdown]
# ## Schedule Database Builder:
#     # Not feasible to run every time, export to csv
#     for t in teams:
#         games = [None]*51
#         for i in range(0,51):
#             try:
#                 table = pd.read_html('https://www.basketball-reference.com/teams/' + t + '/' + str(i+1969) \
#                                      + '_games.html')[0]
#             except:
#                 # print("Failed: " + t + " " + str(i+1969))
#                 continue
#             games[i] = table
#             games[i].drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 8', 'Notes'], inplace=True)
#             games[i].rename(columns={'Unnamed: 7': 'Result'}, inplace=True)
#             games[i].set_index(keys='G', inplace=True)
#             if i < 2000:
#                 games[i].drop(columns=['Start (ET)'], inplace=True)
#             games[i].dropna(inplace=True)
#             if i >= 2000:
#                 games[i]['Date'] = pd.to_datetime(games[i]['Date'] + ' ' + games[i]['Start (ET)'])
#                 games[i].drop(columns=['Start (ET)'], inplace=True)
#             else:
#                 games[i]['Date'] = pd.to_datetime(games[i]['Date'])
#             games[i]['Record'] = games[i]['W'] +'-' + games[i]['L']
#             games[i].drop(columns=['W','L'], inplace=True)
#             games[i]['Margin'] = [int(x) - int(y) for x,y in zip(games[i]['Tm'],games[i]['Opp'])]
#             # print("Checking: " + t + " " + str(i+1969))
#             games[i].to_csv("Schedules/" + t + "_" + str(i + 1969) + '.csv')
#     for t in defunct:
#         games = [None]*51
#         for i in range(0,51):
#             try:
#                 table = pd.read_html('https://www.basketball-reference.com/teams/' + t + '/' + str(i+1969) \
#                                      + '_games.html')[0]
#             except:
#                  print("Failed: " + t + " " + str(i+1969))
#                 continue
#             games[i] = table
#             games[i].drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 8', 'Notes'], inplace=True)
#             games[i].rename(columns={'Unnamed: 7': 'Result'}, inplace=True)
#             games[i].set_index(keys='G', inplace=True)
#             if i < 2000:
#                 games[i].drop(columns=['Start (ET)'], inplace=True)
#             games[i].dropna(inplace=True)
#             if i >= 2000:
#                 games[i]['Date'] = pd.to_datetime(games[i]['Date'] + ' ' + games[i]['Start (ET)'])
#                 games[i].drop(columns=['Start (ET)'], inplace=True)
#             else:
#                 games[i]['Date'] = pd.to_datetime(games[i]['Date'])
#             games[i]['Record'] = games[i]['W'] +'-' + games[i]['L']
#             games[i].drop(columns=['W','L'], inplace=True)
#             games[i]['Margin'] = [int(x) - int(y) for x,y in zip(games[i]['Tm'],games[i]['Opp'])]
#              print("Checking: " + t + " " + str(i+1969))
#             games[i].to_csv("Schedules/DEFUNCT_"+ t + "_" + str(i + 1969) + '.csv')

# %%
schedules = {}
for t in teams:
    games = [None]*51
    for i in range(0,51):
        try:
            games[i] = pd.read_csv('Schedules/' + t + '_' + str(i+1969) + '.csv',index_col='G',
                                   parse_dates=['Date'],infer_datetime_format=True)
        except:
            continue
    schedules[t] = games
# Associate defunct team schedules with current team schedules
for d in defunct:
    games = [None]*51
    for i in range(0,51):
        try:
            games[i] = pd.read_csv('Schedules/' + 'DEFUNCT_' + d + '_' + str(i+1969) + '.csv',index_col='G',
                                  parse_dates=['Date'],infer_datetime_format=True)
            for a in associated:
                for x in associated[a]:
                    if x == d:
                        schedules[a][i] = games[i] 
        except:
            continue

# %%
summary = pd.DataFrame(columns=['Team','W','L','Win_Pct'])
for t in schedules:
    wins = [None]*51
    losses = [None]*51
    i = 0
    for s in schedules[t]:
        try:
            wins[i] = pd.get_dummies(s['Result'])['W'].sum()
            losses[i] = pd.get_dummies(s['Result'])['L'].sum()
            i += 1
        except:
            continue
    wins = [x for x in wins if x is not None]
    losses = [x for x in losses if x is not None]
    win_pct = sum(wins)/(sum(wins) + sum(losses))
    summary = summary.append({'Team': t,'W': sum(wins),'L': sum(losses),'Win_Pct': win_pct}, ignore_index=True)
summary.sort_values(by='Win_Pct',ascending=False,inplace=True)
summary['Rank'] = summary['Win_Pct'].rank(ascending=False).astype(int)
summary.set_index('Rank',inplace=True)
summary
# Out:
#      Team     W     L   Win_Pct
# Rank
# 1     SAS  2162  1316  0.621622
# 2     LAL  2509  1625  0.606918
# 3     BOS  2380  1753  0.575853
# 4     OKC  2260  1874  0.546686
# 5     UTA  1964  1678  0.539264
# 6     POR  2134  1836  0.537531
# 7     HOU  2210  1924  0.534591
# 8     PHO  2186  1948  0.528786
# 9     MIA  1294  1200  0.518845
# 10    CHI  2143  1991  0.518384
# 11    MIL  2129  2005  0.514998
# 12    DET  2078  2056  0.502661
# 13    IND  1744  1733  0.501582
# 14    DAL  1572  1578  0.499048
# 15    ATL  2048  2086  0.495404
# 16    NYK  2039  2095  0.493227
# 17    DEN  1703  1775  0.489649
# 18    PHI  2022  2112  0.489115
# 19    GSW  1996  2138  0.482825
# 20    ORL  1158  1254  0.480100
# 21    TOR   902  1018  0.469792
# 22    NOP   643   735  0.466618
# 23    CLE  1848  2122  0.465491
# 24    WAS  1923  2211  0.465167
# 25    CHO  1027  1303  0.440773
# 26    SAC  1790  2344  0.432995
# 27    BRK  1428  1968  0.420495
# 28    MEM   792  1128  0.412500
# 29    LAC  1610  2360  0.405542
# 30    MIN   961  1451  0.398425

# %%
melted = pd.melt(summary, id_vars='Team', value_vars=['W','L'], var_name='source', value_name='W & L')
plt.figure(figsize=(20,10))
p = sns.barplot(x='Team',y='W & L', hue='source',data=melted)
plt.title('NBA Wins & Losses [1969-2019]', fontweight="bold", fontsize=20)
plt.xlabel('Team')
plt.ylabel('Wins & Losses')
plt.show()

# %%
plt.figure(figsize=(20,10))
p = sns.barplot(x='Team',y='Win_Pct',data=summary)
plt.title('NBA Winning Percentages [1969-2019]', fontweight="bold", fontsize=20)
plt.xlabel('Team')
plt.ylabel('Winning Percentage')
plt.show()

# %%
seasons = {}
for t in schedules:
    seasons[t] = pd.DataFrame(columns=['Year','W','L','Win_Pct'])
    for s in schedules[t]:
        try:
            wins = pd.get_dummies(s['Result'])['W'].sum()
            losses = pd.get_dummies(s['Result'])['L'].sum()
        except:
            continue
        try:
            seasons[t] = seasons[t].append({'Year': pd.DatetimeIndex(s['Date']).year[0], 'W': wins, 
                                            'L': losses, 'Win_Pct': wins/(wins+losses)}, ignore_index=True)
        except:
            continue
    seasons[t].Year = seasons[t].Year.astype(int)
    seasons[t].W = seasons[t].W.astype(int)
    seasons[t].L = seasons[t].L.astype(int)
seasons['PHO']
# Out:
#     Year   W   L   Win_Pct
# 0   1968  16  66  0.195122
# 1   1969  39  43  0.475610
# 2   1970  48  34  0.585366
# 3   1971  49  33  0.597561
# 4   1972  38  44  0.463415
# 5   1973  30  52  0.365854
# 6   1974  32  50  0.390244
# 7   1975  42  40  0.512195
# 8   1976  34  48  0.414634
# 9   1977  49  33  0.597561
# 10  1978  50  32  0.609756
# 11  1979  55  27  0.670732
# 12  1980  57  25  0.695122
# 13  1981  46  36  0.560976
# 14  1982  53  29  0.646341
# 15  1983  41  41  0.500000
# 16  1984  36  46  0.439024
# 17  1985  32  50  0.390244
# 18  1986  36  46  0.439024
# 19  1987  28  54  0.341463
# 20  1988  55  27  0.670732
# 21  1989  54  28  0.658537
# 22  1990  55  27  0.670732
# 23  1991  53  29  0.646341
# 24  1992  62  20  0.756098
# 25  1993  56  26  0.682927
# 26  1994  59  23  0.719512
# 27  1995  41  41  0.500000
# 28  1996  40  42  0.487805
# 29  1997  56  26  0.682927
# 30  1999  27  23  0.540000
# 31  1999  53  29  0.646341
# 32  2000  51  31  0.621951
# 33  2001  36  46  0.439024
# 34  2002  44  38  0.536585
# 35  2003  29  53  0.353659
# 36  2004  62  20  0.756098
# 37  2005  54  28  0.658537
# 38  2006  61  21  0.743902
# 39  2007  55  27  0.670732
# 40  2008  46  36  0.560976
# 41  2009  54  28  0.658537
# 42  2010  40  42  0.487805
# 43  2011  33  33  0.500000
# 44  2012  25  57  0.304878
# 45  2013  48  34  0.585366
# 46  2014  39  43  0.475610
# 47  2015  23  59  0.280488
# 48  2016  24  58  0.292683
# 49  2017  21  61  0.256098
# 50  2018  19  63  0.231707

# %%
melted = pd.melt(seasons['PHO'], id_vars='Year', value_vars=['W','L'], var_name='source', value_name='W & L')
plt.figure(figsize=(20,10))
p = sns.barplot(x='Year',y='W & L', hue='source',data=melted)
plt.title('Phoenix Suns Wins & Losses per Year [1969-2019]', fontweight="bold", fontsize=20)
plt.xlabel('Year')
plt.ylabel('Wins & Losses')
plt.xticks(rotation='vertical')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x='Year', y='Win_Pct', data=seasons['PHO'], ax=ax)
x = seasons['PHO'].Year.values[36]
y = seasons['PHO'].Win_Pct.values[36]
ax.annotate('Steve Nash Era', xy=(x+3.5, y-.32), xycoords='data', size=13, ha='center', textcoords='data')
ax.annotate('', xy=(x, y-.3), xytext=(x+7, y-.3), xycoords='data', textcoords='data',
            arrowprops=dict(arrowstyle='|-|,widthA=0.2,widthB=0.2', color='black'))
plt.title('Phoenix Suns Winning Percentage over Time', fontweight="bold", fontsize=20)
plt.xlabel('Year')
plt.ylabel('Winning Percentage')
plt.show()

# %% [markdown]
# ## Nash Stats
# ___

# %% [markdown]
# ## Nash Database Builder:
#     @contextlib2.contextmanager
#     def quitting(thing):
#         yield thing
#         thing.quit()
#
#     with quitting(webdriver.Firefox()) as driver:
#         link = 'https://www.basketball-reference.com/players/n/nashst01.html'
#         driver.get(link)
#         content = driver.page_source
#         with open('/tmp/out.html', 'wb') as f:
#             f.write(content.encode('utf-8'))
#         data = pd.read_html(content)
#
#     i = 1
#     for d in data[8:13]:
#         d.to_csv('Nash/Table' + str(i) + '.csv')
#         i += 1

# %%
per_game = pd.read_csv('Nash/Table1.csv')
per_game.dropna(inplace=True)
per_game['Season'] = [int(str(x).split('-')[0]) for x in per_game['Season']]
per_game['Age'] = per_game['Age'].astype(int)
per_game['G'] = per_game['G'].astype(int)
per_game['GS'] = per_game['GS'].astype(int)
per_game = per_game[per_game['Season'] >= 2004]
per_game = per_game[per_game['Season'] <= 2011]
per_game.reset_index(inplace=True,drop=True)
per_game.drop(columns=['Unnamed: 0'],inplace=True)
per_game
# Out:
#    Season  Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0    2004   30  PHO  NBA  PG  75  75  34.3  5.7  11.4  ...  0.887  0.8  2.6
# 1    2005   31  PHO  NBA  PG  79  79  35.4  6.8  13.4  ...  0.921  0.6  3.6
# 2    2006   32  PHO  NBA  PG  76  76  35.3  6.8  12.8  ...  0.899  0.4  3.1
# 3    2007   33  PHO  NBA  PG  81  81  34.3  6.0  11.9  ...  0.906  0.3  3.1
# 4    2008   34  PHO  NBA  PG  74  74  33.6  5.8  11.5  ...  0.933  0.3  2.8
# 5    2009   35  PHO  NBA  PG  81  81  32.8  6.2  12.2  ...  0.938  0.4  2.9
# 6    2010   36  PHO  NBA  PG  75  75  33.3  5.3  10.8  ...  0.912  0.5  2.9
# 7    2011   37  PHO  NBA  PG  62  62  31.6  4.8   9.0  ...  0.894  0.4  2.6
#
#    TRB   AST  STL  BLK  TOV   PF   PTS
# 0  3.3  11.5  1.0  0.1  3.3  1.8  15.5
# 1  4.2  10.5  0.8  0.2  3.5  1.5  18.8
# 2  3.5  11.6  0.8  0.1  3.8  1.5  18.6
# 3  3.5  11.1  0.7  0.1  3.6  1.4  16.9
# 4  3.0   9.7  0.7  0.1  3.4  1.5  15.7
# 5  3.3  11.0  0.5  0.1  3.6  1.3  16.5
# 6  3.5  11.4  0.6  0.1  3.5  1.2  14.7
# 7  3.0  10.7  0.6  0.1  3.7  0.9  12.5
#
# [8 rows x 30 columns]

# %%
per_36 = pd.read_csv('Nash/Table3.csv')
per_36.dropna(inplace=True)
per_36['Season'] = [int(str(x).split('-')[0]) for x in per_36['Season']]
per_36['Age'] = per_36['Age'].astype(int)
per_36['G'] = per_36['G'].astype(int)
per_36['GS'] = per_36['GS'].astype(int)
per_36['MP'] = per_36['MP'].astype(int)
per_36 = per_36[per_36['Season'] >= 2004]
per_36 = per_36[per_36['Season'] <= 2011]
per_36.reset_index(inplace=True,drop=True)
per_36.drop(columns=['Unnamed: 0'],inplace=True)
per_36
# Out:
#    Season  Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0    2004   30  PHO  NBA  PG  75  75  2573  6.0  12.0  ...  0.887  0.8  2.7
# 1    2005   31  PHO  NBA  PG  79  79  2796  7.0  13.6  ...  0.921  0.6  3.7
# 2    2006   32  PHO  NBA  PG  76  76  2682  6.9  13.0  ...  0.899  0.4  3.2
# 3    2007   33  PHO  NBA  PG  81  81  2780  6.3  12.5  ...  0.906  0.4  3.3
# 4    2008   34  PHO  NBA  PG  74  74  2484  6.2  12.3  ...  0.933  0.3  3.0
# 5    2009   35  PHO  NBA  PG  81  81  2660  6.8  13.3  ...  0.938  0.5  3.2
# 6    2010   36  PHO  NBA  PG  75  75  2497  5.8  11.7  ...  0.912  0.6  3.2
# 7    2011   37  PHO  NBA  PG  62  62  1961  5.4  10.2  ...  0.894  0.5  2.9
#
#    TRB   AST  STL  BLK  TOV   PF   PTS
# 0  3.5  12.0  1.0  0.1  3.4  1.9  16.3
# 1  4.3  10.6  0.8  0.2  3.6  1.5  19.2
# 2  3.6  11.9  0.8  0.1  3.9  1.6  19.0
# 3  3.7  11.6  0.7  0.1  3.8  1.5  17.8
# 4  3.2  10.4  0.8  0.1  3.6  1.6  16.8
# 5  3.6  12.1  0.6  0.2  4.0  1.5  18.0
# 6  3.7  12.3  0.7  0.1  3.8  1.3  15.9
# 7  3.4  12.2  0.7  0.1  4.2  1.0  14.2
#
# [8 rows x 29 columns]

# %%
totals = pd.read_csv('Nash/Table2.csv')
totals.dropna(inplace=True)
totals['Season'] = [int(str(x).split('-')[0]) for x in totals['Season']]
totals['Age'] = totals['Age'].astype(int)
totals['G'] = totals['G'].astype(int)
totals['GS'] = totals['GS'].astype(int)
totals = totals[totals['Season'] >= 2004]
totals = totals[totals['Season'] <= 2011]
totals.reset_index(inplace=True,drop=True)
totals.drop(columns=['Unnamed: 0'],inplace=True)
totals
# Out:
#    Season  Age   Tm   Lg Pos   G  GS      MP     FG     FGA  ...    FT%   ORB  \
# 0    2004   30  PHO  NBA  PG  75  75  2573.0  430.0   857.0  ...  0.887  57.0
# 1    2005   31  PHO  NBA  PG  79  79  2796.0  541.0  1056.0  ...  0.921  47.0
# 2    2006   32  PHO  NBA  PG  76  76  2682.0  517.0   971.0  ...  0.899  30.0
# 3    2007   33  PHO  NBA  PG  81  81  2780.0  485.0   962.0  ...  0.906  28.0
# 4    2008   34  PHO  NBA  PG  74  74  2484.0  428.0   851.0  ...  0.933  19.0
# 5    2009   35  PHO  NBA  PG  81  81  2660.0  499.0   985.0  ...  0.938  34.0
# 6    2010   36  PHO  NBA  PG  75  75  2497.0  399.0   811.0  ...  0.912  40.0
# 7    2011   37  PHO  NBA  PG  62  62  1961.0  295.0   555.0  ...  0.894  26.0
#
#      DRB    TRB    AST   STL   BLK    TOV     PF     PTS
# 0  192.0  249.0  861.0  74.0   6.0  245.0  136.0  1165.0
# 1  286.0  333.0  826.0  61.0  12.0  276.0  120.0  1489.0
# 2  239.0  269.0  884.0  57.0   6.0  287.0  117.0  1412.0
# 3  254.0  282.0  898.0  53.0   5.0  295.0  113.0  1371.0
# 4  204.0  223.0  717.0  55.0  10.0  248.0  108.0  1160.0
# 5  234.0  268.0  892.0  42.0  12.0  295.0  108.0  1333.0
# 6  220.0  260.0  855.0  48.0   4.0  265.0   87.0  1106.0
# 7  160.0  186.0  664.0  38.0   8.0  229.0   53.0   772.0
#
# [8 rows x 30 columns]

# %%
per_100 = pd.read_csv('Nash/Table4.csv').drop(columns=['Unnamed: 29'])
per_100.dropna(inplace=True)
per_100['Season'] = [int(str(x).split('-')[0]) for x in per_100['Season']]
per_100['Age'] = per_100['Age'].astype(int)
per_100['G'] = per_100['G'].astype(int)
per_100['GS'] = per_100['GS'].astype(int)
per_100 = per_100[per_100['Season'] >= 2004]
per_100 = per_100[per_100['Season'] <= 2011]
per_100.reset_index(inplace=True,drop=True)
per_100.drop(columns=['Unnamed: 0'],inplace=True)
per_100
# Out:
#    Season  Age   Tm   Lg Pos   G  GS      MP   FG   FGA  ...  DRB  TRB   AST  \
# 0    2004   30  PHO  NBA  PG  75  75  2573.0  8.4  16.7  ...  3.7  4.8  16.7
# 1    2005   31  PHO  NBA  PG  79  79  2796.0  9.7  18.9  ...  5.1  6.0  14.8
# 2    2006   32  PHO  NBA  PG  76  76  2682.0  9.7  18.2  ...  4.5  5.0  16.5
# 3    2007   33  PHO  NBA  PG  81  81  2780.0  8.7  17.2  ...  4.5  5.0  16.0
# 4    2008   34  PHO  NBA  PG  74  74  2484.0  8.6  17.1  ...  4.1  4.5  14.4
# 5    2009   35  PHO  NBA  PG  81  81  2660.0  9.4  18.6  ...  4.4  5.1  16.9
# 6    2010   36  PHO  NBA  PG  75  75  2497.0  8.1  16.5  ...  4.5  5.3  17.4
# 7    2011   37  PHO  NBA  PG  62  62  1961.0  7.8  14.7  ...  4.2  4.9  17.5
#
#    STL  BLK  TOV   PF   PTS   ORtg   DRtg
# 0  1.4  0.1  4.8  2.6  22.7  123.0  111.0
# 1  1.1  0.2  4.9  2.1  26.7  121.0  109.0
# 2  1.1  0.1  5.4  2.2  26.4  124.0  110.0
# 3  0.9  0.1  5.3  2.0  24.5  121.0  112.0
# 4  1.1  0.2  5.0  2.2  23.4  119.0  115.0
# 5  0.8  0.2  5.6  2.0  25.2  121.0  114.0
# 6  1.0  0.1  5.4  1.8  22.5  118.0  114.0
# 7  1.0  0.2  6.1  1.4  20.4  115.0  110.0
#
# [8 rows x 31 columns]

# %%
advanced = pd.read_csv('Nash/Table5.csv').drop(columns=['Unnamed: 19', 'Unnamed: 24'])
advanced.dropna(inplace=True)
advanced['Season'] = [int(str(x).split('-')[0]) for x in advanced['Season']]
advanced['Age'] = advanced['Age'].astype(int)
advanced['G'] = advanced['G'].astype(int)
advanced['MP'] = advanced['MP'].astype(int)
advanced = advanced[advanced['Season'] >= 2004]
advanced = advanced[advanced['Season'] <= 2011]
advanced.reset_index(inplace=True,drop=True)
advanced.drop(columns=['Unnamed: 0'],inplace=True)
advanced
# Out:
#    Season  Age   Tm   Lg Pos   G    MP   PER    TS%   3PAr  ...  TOV%  USG%  \
# 0    2004   30  PHO  NBA  PG  75  2573  22.0  0.606  0.254  ...  20.3  20.5
# 1    2005   31  PHO  NBA  PG  79  2796  23.3  0.632  0.324  ...  19.0  23.3
# 2    2006   32  PHO  NBA  PG  76  2682  23.8  0.654  0.353  ...  21.0  22.9
# 3    2007   33  PHO  NBA  PG  81  2780  21.1  0.641  0.396  ...  21.6  22.0
# 4    2008   34  PHO  NBA  PG  74  2484  19.5  0.615  0.289  ...  20.8  21.1
# 5    2009   35  PHO  NBA  PG  81  2660  21.6  0.615  0.295  ...  21.4  22.9
# 6    2010   36  PHO  NBA  PG  75  2497  20.8  0.601  0.253  ...  22.4  21.4
# 7    2011   37  PHO  NBA  PG  62  1961  20.3  0.625  0.254  ...  27.1  19.6
#
#     OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   9.7  1.2  10.9  0.203   4.5  -2.9  1.7   2.4
# 1  10.3  2.1  12.4  0.212   5.4  -1.6  3.7   4.0
# 2  10.8  1.7  12.6  0.225   6.1  -2.3  3.8   3.9
# 3   9.0  1.4  10.5  0.181   4.8  -3.2  1.6   2.6
# 4   6.7  0.5   7.3  0.140   3.5  -3.4  0.0   1.3
# 5   9.1  0.8   9.9  0.178   4.9  -3.1  1.8   2.6
# 6   7.3  0.7   7.9  0.153   3.6  -3.0  0.6   1.6
# 7   5.2  0.6   5.9  0.144   2.9  -3.5 -0.5   0.7
#
# [8 rows x 27 columns]

# %%
team = [None]*8
opp = [None]*8
diff = [None]*8
for i in range(0,8):
    onoff = pd.read_html('https://www.basketball-reference.com/players/n/nashst01/on-off/' + str(2005+i))[0]
    team[i] = onoff['Team'].copy(deep=True)
    team[i]['Split'] = {'On Court', 'Off Court', 'On-Off'}
    team[i].set_index('Split',inplace=True)
    opp[i] = onoff['Opponent'].copy(deep=True)
    opp[i]['Split'] = {'On Court', 'Off Court', 'On-Off'}
    opp[i].set_index('Split',inplace=True)
    diff[i] = onoff['Opponent'].copy(deep=True)
    diff[i]['Split'] = {'On Court', 'Off Court', 'On-Off'}
    diff[i].set_index('Split',inplace=True)

# %%
for i in range(0,8):
    print(str(2004+i) + '-' + str(2005+i))
    print(team[i])
# Out:
# 2004-2005
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.555  27.9  67.6  48.7  60.8   7.7   7.1  12.6  120.3
# On Court   0.494  26.7  69.4  49.3  50.3   6.2   8.4  17.1  102.9
# Off Court  0.061   1.2  -1.8  -0.6  10.5   1.5  -1.3  -4.5   17.4
# 2005-2006
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.545  22.1  72.4  48.0  64.6   7.1   7.0  13.3  114.2
# On Court   0.518  22.2  71.2  47.0  61.0   6.4   7.6  14.6  106.2
# Off Court  0.027  -0.1   1.2   1.0   3.6   0.7  -0.6  -1.3    8.0
# 2006-2007
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.576  23.0  71.3  49.2  64.5   7.0   7.2  15.0  118.6
# On Court   0.500  22.3  73.4  47.4  58.1   7.0   6.3  15.2  105.6
# Off Court  0.076   0.7  -2.1   1.8   6.4   0.0   0.9  -0.2   13.0
# 2007-2008
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.575  23.1  71.7  49.7  65.8   7.1   8.1  14.9  118.2
# On Court   0.494  20.8  69.1  46.1  61.0   5.6   9.7  14.9  102.8
# Off Court  0.081   2.3   2.6   3.6   4.8   1.5  -1.6   0.0   15.4
# 2008-2009
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.568  25.4  71.9  50.4  58.7   6.5   7.5  15.6  116.7
# On Court   0.507  31.2  71.5  50.8  52.2   9.1   8.3  17.6  108.6
# Off Court  0.061  -5.8   0.4  -0.4   6.5  -2.6  -0.8  -2.0    8.1
# 2009-2010
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.559  26.0  70.9  50.2  57.8   5.4   6.6  14.7  117.7
# On Court   0.517  30.6  70.5  50.8  55.9   7.7   9.5  17.2  111.3
# Off Court  0.042  -4.6   0.4  -0.6   1.9  -2.3  -2.9  -2.5    6.4
# 2010-2011
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.541  23.4  71.5  47.9  63.5   6.4   6.3  14.2  114.3
# On Court   0.488  24.1  71.7  47.1  54.5   7.9   7.1  16.2  102.3
# Off Court  0.053  -0.7  -0.2   0.8   9.0  -1.5  -0.8  -2.0   12.0
# 2011-2012
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.494  28.7  77.0  50.8  48.0   7.3   6.1  15.7  107.1
# On Court   0.488  26.6  77.7  52.6  47.4   7.0   6.5  15.7  105.8
# Off Court  0.006   2.1  -0.7  -1.8   0.6   0.3  -0.4   0.0    1.3
# 2007-2008
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.493  28.3  76.9  50.3  49.2   7.8   5.7  13.9  108.3
# On Court   0.477  30.9  79.2  53.9  44.2   7.1   7.4  13.5  107.3
# Off Court  0.016  -2.6  -2.3  -3.6   5.0   0.7  -1.7   0.4    1.0
# 2008-2009
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.509  28.1  74.6  49.6  53.5   8.9   6.4  13.8  112.1
# On Court   0.515  28.5  68.8  49.2  52.4   9.1   8.1  16.4  111.0
# Off Court -0.006  -0.4   5.8   0.4   1.1  -0.2  -1.7  -2.6    1.1
# 2009-2010
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.492  29.1  74.0  49.8  51.7   8.5   6.3  12.6  111.0
# On Court   0.488  29.5  69.4  49.2  54.8   7.8   9.5  15.7  108.6
# Off Court  0.004  -0.4   4.6   0.6  -3.1   0.7  -3.2  -3.1    2.4
# 2010-2011
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.505  28.5  76.6  52.1  57.0   8.1   6.9  15.0  109.7
# On Court   0.527  28.3  75.9  52.9  57.3   8.5   7.5  15.5  112.5
# Off Court -0.022   0.2   0.7  -0.8  -0.3  -0.4  -0.6  -0.5   -2.8
# 2011-2012
#             eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
# Split
# On-Off     0.484  27.5  75.3  50.4  57.3   9.1   6.3  14.3  105.8
# On Court   0.503  29.7  72.6  52.0  55.2   7.8   8.1  16.8  108.6
# Off Court -0.019  -2.2   2.7  -1.6   2.1   1.3  -1.8  -2.5   -2.8

# %% [markdown]
# ## MVP Stats
# ___

# %% [markdown]
# ## MVP Statistics Database Builder
#     i = 0
#     for m in mvp:
#         if not (os.path.isfile('MVP/' + m + '/' + 'Table' + '_1.csv')):
#             @contextlib2.contextmanager
#             def quitting(thing):
#                 yield thing
#                 thing.quit()
#
#             with quitting(webdriver.Firefox()) as driver:
#                 link = 'https://www.basketball-reference.com/players/' + m + '.html'
#                 driver.get(link)
#                 content = driver.page_source
#                 with open('/tmp/out.html', 'wb') as f:
#                     f.write(content.encode('utf-8'))
#                 data = pd.read_html(content)
#
#             # Split Retired players and unretired(or just retired) players because there is an extra table on current
#             # player pages
#             if (m in ['i/iversal01', 'd/duncati01', 'g/garneke01', 'n/nashst01', 'b/bryanko']):
#                 j = 1
#                 for d in data[8:13]:
#                     d.to_csv('MVP/' + m + '/' + 'Table' + '_' + str(j) + '.csv')
#                     j += 1
#             else:
#                 j = 1
#                 for d in data[9:14]:
#                     d.to_csv('MVP/' + m + '/' + 'Table' + '_' + str(j) + '.csv')
#                     j += 1
#
#         onoff = pd.read_html('https://www.basketball-reference.com/players/' + m + '/on-off/' + str(i+2001))[0]
#         team = onoff['Team'].copy(deep=True)
#         team['Split'] = {'On Court', 'Off Court', 'On-Off'}
#         team.set_index('Split',inplace=True)
#         team.to_csv('MVP/' + m + '/' + str(i+2000) + '_' + 'OnOff[Team]' + '.csv')
#         opp = onoff['Opponent'].copy(deep=True)
#         opp['Split'] = {'On Court', 'Off Court', 'On-Off'}
#         opp.set_index('Split',inplace=True)
#         opp.to_csv('MVP/' + m + '/' + str(i+2000) + '_' + 'OnOff[Opp]' + '.csv')
#         diff = onoff['Opponent'].copy(deep=True)
#         diff['Split'] = {'On Court', 'Off Court', 'On-Off'}
#         diff.set_index('Split',inplace=True)
#         diff.to_csv('MVP/' + m + '/' + str(i+2000) + '_' + 'OnOff[Diff]' + '.csv')
#         i += 1

# %%
m = 'a/antetgi01'
@contextlib2.contextmanager
def quitting(thing):
    yield thing
    thing.quit()

with quitting(webdriver.Firefox()) as driver:
    link = 'https://www.basketball-reference.com/players/' + m + '.html' 
    driver.get(link)
    content = driver.page_source
    with open('/tmp/out.html', 'wb') as f:
        f.write(content.encode('utf-8'))
    data = pd.read_html(content)

j = 1
for d in data[9:14]:
    d.to_csv('MVP/' + m + '/' + 'Table' + '_' + str(j) + '.csv')
    j += 1

# %%
per_game = {}
for m in mvp:
    n = mvp_names[m]
    per_game[n] = pd.read_csv('MVP/' + m + '/' + 'Table' + '_1.csv')
    per_game[n].replace('Did Not Play\xa0(injury—ACL)',np.nan,inplace=True)
    per_game[n].dropna(inplace=True)
    per_game[n]['Season'] = [int(str(x).split('-')[0]) for x in per_game[n]['Season']]
    per_game[n]['Age'] = per_game[n]['Age'].astype(int)
    per_game[n]['G'] = per_game[n]['G'].astype(int)
    per_game[n]['GS'] = per_game[n]['GS'].astype(int)
    per_game[n] = per_game[n][per_game[n]['Season'].isin(mvp_years[n])]
    per_game[n].reset_index(inplace=True,drop=True)
    per_game[n].drop(columns=['Unnamed: 0'],inplace=True)
    per_game[n] = per_game[n].loc[:, ['Season', 'Tm', 'Pos', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
                                      'FG%', '3P%', 'eFG%', 'FT%']]
per_game
# Out:
# {'Allen Iverson':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV   FG%   3P%  \
#  0    2000  PHI  SG  71  42.0  31.1  3.8  4.6  2.5  0.3  3.3  0.42  0.32
#
#      eFG%    FT%
#  0  0.447  0.814  ,
#  'Tim Duncan':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2001  SAS  PF  82  40.6  25.5  12.7  3.7  0.7  2.5  3.2  0.508  0.100
#  1    2002  SAS  PF  81  39.3  23.3  12.9  3.9  0.7  2.9  3.1  0.513  0.273
#
#      eFG%    FT%
#  0  0.508  0.799
#  1  0.515  0.710  ,
#  'Kevin Garnett':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2003  MIN  PF  82  39.4  24.2  13.9  5.0  1.5  2.2  2.6  0.499  0.256
#
#      eFG%    FT%
#  0  0.502  0.791  ,
#  'Steve Nash':    Season   Tm Pos   G    MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2004  PHO  PG  75  34.3  15.5  3.3  11.5  1.0  0.1  3.3  0.502  0.431
#  1    2005  PHO  PG  79  35.4  18.8  4.2  10.5  0.8  0.2  3.5  0.512  0.439
#
#      eFG%    FT%
#  0  0.557  0.887
#  1  0.583  0.921  ,
#  'Dirk Nowitzki':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2006  DAL  PF  78  36.2  24.6  8.9  3.4  0.7  0.8  2.1  0.502  0.416
#
#      eFG%    FT%
#  0  0.529  0.904  ,
#  'Kobe Bryant':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2007  LAL  SG  82  38.9  28.3  6.3  5.4  1.8  0.5  3.1  0.459  0.361
#
#      eFG%   FT%
#  0  0.503  0.84  ,
#  'LeBron James':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2008  CLE  SF  81  37.7  28.4  7.6  7.2  1.7  1.1  3.0  0.489  0.344
#  1    2009  CLE  SF  76  39.0  29.7  7.3  8.6  1.6  1.0  3.4  0.503  0.333
#  2    2011  MIA  SF  62  37.5  27.1  7.9  6.2  1.9  0.8  3.4  0.531  0.362
#  3    2012  MIA  PF  76  37.9  26.8  8.0  7.3  1.7  0.9  3.0  0.565  0.406
#
#      eFG%    FT%
#  0  0.530  0.780
#  1  0.545  0.767
#  2  0.554  0.771
#  3  0.603  0.753  ,
#  'Derrick Rose':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV   FG%   3P%  eFG%  \
#  0    2010  CHI  PG  81  37.4  25.0  4.1  7.7  1.0  0.6  3.4  .445  .332  .485
#
#      FT%
#  0  .858  ,
#  'Kevin Durant':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2013  OKC  SF  81  38.5  32.0  7.4  5.5  1.3  0.7  3.5  0.503  0.391
#
#     eFG%    FT%
#  0  0.56  0.873  ,
#  'Stephen Curry':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2014  GSW  PG  80  32.7  23.8  4.3  7.7  2.0  0.2  3.1  0.487  0.443
#  1    2015  GSW  PG  79  34.2  30.1  5.4  6.7  2.1  0.2  3.3  0.504  0.454
#
#      eFG%    FT%
#  0  0.594  0.914
#  1  0.630  0.908  ,
#  'Russell Westbrook':    Season   Tm Pos   G    MP   PTS   TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2016  OKC  PG  81  34.6  31.6  10.7  10.4  1.6  0.4  5.4  0.425  0.343
#
#      eFG%    FT%
#  0  0.476  0.845  ,
#  'James Harden':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2017  HOU  SG  72  35.4  30.4  5.4  8.8  1.8  0.7  4.4  0.449  0.367
#
#      eFG%    FT%
#  0  0.541  0.858  ,
#  'Giannis Antetokounmpo':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2018  MIL  PF  72  32.8  27.7  12.5  5.9  1.3  1.5  3.7  0.578  0.256
#
#      eFG%    FT%
#  0  0.599  0.729  }

# %%
totals = {}
for m in mvp:
    n = mvp_names[m]
    totals[n] = pd.read_csv('MVP/' + m + '/' + 'Table' + '_2.csv')
    totals[n].replace('Did Not Play\xa0(injury—ACL)',np.nan,inplace=True)
    totals[n].dropna(inplace=True)
    totals[n]['Season'] = [int(str(x).split('-')[0]) for x in totals[n]['Season']]
    totals[n]['Age'] = totals[n]['Age'].astype(int)
    totals[n]['G'] = totals[n]['G'].astype(int)
    totals[n]['GS'] = totals[n]['GS'].astype(int)
    totals[n] = totals[n][totals[n]['Season'].isin(mvp_years[n])]
    totals[n].reset_index(inplace=True,drop=True)
    totals[n].drop(columns=['Unnamed: 0'],inplace=True)
    totals[n] = totals[n].loc[:, ['Season', 'Tm', 'Pos', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2016  OKC  PG  81  2802  2558  864  840  132   31  438  0.425  0.343
#
#      eFG%    FT%
#  0  0.476  0.845  ,
#  'James Harden':    Season   Tm Pos   G      MP     PTS    TRB    AST    STL   BLK    TOV  \
#  0    2017  HOU  SG  72  2551.0  2191.0  389.0  630.0  126.0  50.0  315.0
#
#       FG%    3P%   eFG%    FT%
#  0  0.449  0.367  0.541  0.858  ,
#  'Giannis Antetokounmpo':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2018  MIL  PF  72  2358  1994  898  424   92  110  268  0.578  0.256
#
#      eFG%    FT%
#  0  0.599  0.729  }

# %%
per_36 = {}
for m in mvp:
    n = mvp_names[m]
    per_36[n] = pd.read_csv('MVP/' + m + '/' + 'Table' + '_3.csv')
    per_36[n].replace('Did Not Play\xa0(injury—ACL)',np.nan,inplace=True)
    per_36[n].dropna(inplace=True)
    per_36[n]['Season'] = [int(str(x).split('-')[0]) for x in per_36[n]['Season']]
    per_36[n]['Age'] = per_36[n]['Age'].astype(int)
    per_36[n]['G'] = per_36[n]['G'].astype(int)
    per_36[n]['GS'] = per_36[n]['GS'].astype(int)
    per_36[n] = per_36[n][per_36[n]['Season'].isin(mvp_years[n])]
    per_36[n].reset_index(inplace=True,drop=True)
    per_36[n].drop(columns=['Unnamed: 0'],inplace=True)
    per_36[n] = per_36[n].loc[:, ['Season', 'Tm', 'Pos', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
                                      'FG%', '3P%', 'eFG%', 'FT%']]
per_36
# Out:
# {'Allen Iverson':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV   FG%   3P%  \
#  0    2000  PHI  SG  71  2979.0  26.7  3.3  3.9  2.2  0.2  2.9  0.42  0.32
#
#     eFG%    FT%
#  0   NaN  0.814  ,
#  'Tim Duncan':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2001  SAS  PF  82  3329  22.6  11.3  3.3  0.7  2.2  2.8  0.508  0.100
#  1    2002  SAS  PF  81  3181  21.3  11.8  3.6  0.6  2.7  2.8  0.513  0.273
#
#     eFG%    FT%
#  0   NaN  0.799
#  1   NaN  0.710  ,
#  'Kevin Garnett':    Season   Tm Pos   G      MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2003  MIN  PF  82  3231.0  22.1  12.7  4.6  1.3  2.0  2.4  0.499  0.256
#
#     eFG%    FT%
#  0   NaN  0.791  ,
#  'Steve Nash':    Season   Tm Pos   G      MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2004  PHO  PG  75  2573.0  16.3  3.5  12.0  1.0  0.1  3.4  0.502  0.431
#  1    2005  PHO  PG  79  2796.0  19.2  4.3  10.6  0.8  0.2  3.6  0.512  0.439
#
#     eFG%    FT%
#  0   NaN  0.887
#  1   NaN  0.921  ,
#  'Dirk Nowitzki':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2006  DAL  PF  78  2820  24.5  8.8  3.4  0.7  0.8  2.1  0.502  0.416
#
#     eFG%    FT%
#  0   NaN  0.904  ,
#  'Kobe Bryant':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2007  LAL  SG  82  3192  26.2  5.8  5.0  1.7  0.5  2.9  0.459  0.361
#
#     eFG%   FT%
#  0   NaN  0.84  ,
#  'LeBron James':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2008  CLE  SF  81  3054.0  27.2  7.2  6.9  1.6  1.1  2.8  0.489  0.344
#  1    2009  CLE  SF  76  2966.0  27.4  6.7  7.9  1.5  0.9  3.2  0.503  0.333
#  2    2011  MIA  SF  62  2326.0  26.0  7.6  6.0  1.8  0.8  3.3  0.531  0.362
#  3    2012  MIA  PF  76  2877.0  25.5  7.6  6.9  1.6  0.8  2.8  0.565  0.406
#
#     eFG%    FT%
#  0   NaN  0.780
#  1   NaN  0.767
#  2   NaN  0.771
#  3   NaN  0.753  ,
#  'Derrick Rose':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2010  CHI  PG  81  3026.0  24.1  3.9  7.4  1.0  0.6  3.3  0.445  0.332
#
#     eFG%    FT%
#  0   NaN  0.858  ,
#  'Kevin Durant':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2013  OKC  SF  81  3122.0  29.9  6.9  5.1  1.2  0.7  3.3  0.503  0.391
#
#     eFG%    FT%
#  0   NaN  0.873  ,
#  'Stephen Curry':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2014  GSW  PG  80  2613  26.2  4.7  8.5  2.2  0.2  3.4  0.487  0.443
#  1    2015  GSW  PG  79  2700  31.7  5.7  7.0  2.3  0.2  3.5  0.504  0.454
#
#     eFG%    FT%
#  0   NaN  0.914
#  1   NaN  0.908  ,
#  'Russell Westbrook':    Season   Tm Pos   G    MP   PTS   TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2016  OKC  PG  81  2802  32.9  11.1  10.8  1.7  0.4  5.6  0.425  0.343
#
#     eFG%    FT%
#  0   NaN  0.845  ,
#  'James Harden':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2017  HOU  SG  72  2551.0  30.9  5.5  8.9  1.8  0.7  4.4  0.449  0.367
#
#     eFG%    FT%
#  0   NaN  0.858  ,
#  'Giannis Antetokounmpo':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2018  MIL  PF  72  2358  30.4  13.7  6.5  1.4  1.7  4.1  0.578  0.256
#
#     eFG%    FT%
#  0   NaN  0.729  }

# %%
per_100 = {}
for m in mvp:
    n = mvp_names[m]
    per_100[n] = pd.read_csv('MVP/' + m + '/' + 'Table' + '_4.csv')
    per_100[n].replace('Did Not Play\xa0(injury—ACL)',np.nan,inplace=True)
    if 'Unnamed: 29' in per_100[n].columns:
        per_100[n].drop(columns=['Unnamed: 29'],inplace=True)
    per_100[n].dropna(inplace=True)
    per_100[n]['Season'] = [int(str(x).split('-')[0]) for x in per_100[n]['Season']]
    per_100[n]['Age'] = per_100[n]['Age'].astype(int)
    per_100[n]['G'] = per_100[n]['G'].astype(int)
    per_100[n]['GS'] = per_100[n]['GS'].astype(int)
    per_100[n] = per_100[n][per_100[n]['Season'].isin(mvp_years[n])]
    per_100[n].reset_index(inplace=True,drop=True)
    per_100[n].drop(columns=['Unnamed: 0'],inplace=True)
    per_100[n] = per_100[n].loc[:, ['Season', 'Tm', 'Pos', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
                                      'FG%', '3P%', 'FT%']]
per_100
# Out:
# {'Allen Iverson':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV   FG%   3P%  \
#  0    2000  PHI  SG  71  2979.0  39.3  4.9  5.8  3.2  0.4  4.2  0.42  0.32
#
#       FT%
#  0  0.814  ,
#  'Tim Duncan':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2001  SAS  PF  82  3329  33.5  16.7  4.9  1.0  3.3  4.2  0.508  0.100
#  1    2002  SAS  PF  81  3181  31.6  17.5  5.3  0.9  4.0  4.2  0.513  0.273
#
#       FT%
#  0  0.799
#  1  0.710  ,
#  'Kevin Garnett':    Season   Tm Pos   G      MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2003  MIN  PF  82  3231.0  33.2  19.0  6.8  2.0  3.0  3.5  0.499  0.256
#
#       FT%
#  0  0.791  ,
#  'Steve Nash':    Season   Tm Pos   G      MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2004  PHO  PG  75  2573.0  22.7  4.8  16.7  1.4  0.1  4.8  0.502  0.431
#  1    2005  PHO  PG  79  2796.0  26.7  6.0  14.8  1.1  0.2  4.9  0.512  0.439
#
#       FT%
#  0  0.887
#  1  0.921  ,
#  'Dirk Nowitzki':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2006  DAL  PF  78  2820  36.4  13.2  5.0  1.0  1.2  3.2  0.502  0.416
#
#       FT%
#  0  0.904  ,
#  'Kobe Bryant':    Season   Tm Pos   G    MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2007  LAL  SG  82  3192  36.5  8.1  6.9  2.4  0.6  4.0  0.459  0.361
#
#      FT%
#  0  0.84  ,
#  'LeBron James':    Season   Tm Pos   G      MP   PTS   TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2008  CLE  SF  81  3054.0  40.8  10.9  10.4  2.4  1.6  4.3  0.489  0.344
#  1    2009  CLE  SF  76  2966.0  40.0   9.8  11.5  2.2  1.4  4.6  0.503  0.333
#  2    2011  MIA  SF  62  2326.0  38.1  11.1   8.8  2.6  1.1  4.8  0.531  0.362
#  3    2012  MIA  PF  76  2877.0  37.5  11.2  10.1  2.4  1.2  4.2  0.565  0.406
#
#       FT%
#  0  0.780
#  1  0.767
#  2  0.771
#  3  0.753  ,
#  'Derrick Rose':    Season   Tm Pos   G      MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2010  CHI  PG  81  3026.0  35.6  5.8  10.9  1.5  0.9  4.9  0.445  0.332
#
#       FT%
#  0  0.858  ,
#  'Kevin Durant':    Season   Tm Pos   G      MP   PTS  TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2013  OKC  SF  81  3122.0  41.8  9.6  7.2  1.7  1.0  4.6  0.503  0.391
#
#       FT%
#  0  0.873  ,
#  'Stephen Curry':    Season   Tm Pos   G    MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2014  GSW  PG  80  2613  35.5  6.4  11.6  3.0  0.3  4.7  0.487  0.443
#  1    2015  GSW  PG  79  2700  42.5  7.7   9.4  3.0  0.3  4.7  0.504  0.454
#
#       FT%
#  0  0.914
#  1  0.908  ,
#  'Russell Westbrook':    Season   Tm Pos   G    MP   PTS   TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2016  OKC  PG  81  2802  44.8  15.1  14.7  2.3  0.5  7.7  0.425  0.343
#
#       FT%
#  0  0.845  ,
#  'James Harden':    Season   Tm Pos   G      MP   PTS  TRB   AST  STL  BLK  TOV    FG%    3P%  \
#  0    2017  HOU  SG  72  2551.0  42.3  7.5  12.2  2.4  1.0  6.1  0.449  0.367
#
#       FT%
#  0  0.858  ,
#  'Giannis Antetokounmpo':    Season   Tm Pos   G    MP   PTS   TRB  AST  STL  BLK  TOV    FG%    3P%  \
#  0    2018  MIL  PF  72  2358  39.3  17.7  8.4  1.8  2.2  5.3  0.578  0.256
#
#       FT%
#  0  0.729  }

# %%
advanced = {}
for m in mvp:
    n = mvp_names[m]
    advanced[n] = pd.read_csv('MVP/' + m + '/' + 'Table' + '_5.csv')
    if 'Unnamed: 19' in advanced[n].columns:
        advanced[n].drop(columns=['Unnamed: 19', 'Unnamed: 24'],inplace=True)
    advanced[n].replace('Did Not Play\xa0(injury—ACL)',np.nan,inplace=True)
    advanced[n].dropna(inplace=True)
    advanced[n]['Season'] = [int(str(x).split('-')[0]) for x in advanced[n]['Season']]
    advanced[n]['Age'] = advanced[n]['Age'].astype(int)
    advanced[n]['G'] = advanced[n]['G'].astype(int)
    advanced[n] = advanced[n][advanced[n]['Season'].isin(mvp_years[n])]
    advanced[n].reset_index(inplace=True,drop=True)
    advanced[n].drop(columns=['Unnamed: 0'],inplace=True)
    advanced[n] = advanced[n].loc[:, ['Season', 'Tm', 'Pos', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'TRB%', 
                                      'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 
                                     'OBPM', 'DBPM', 'BPM', 'VORP']]
advanced
# Out:
# {'Allen Iverson':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2000  PHI  SG  71  2979.0  24.0  0.518  0.169  0.397   5.2  ...  10.0
#
#     USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  35.9  7.3  4.5  11.8   0.19   5.0  -0.1  4.8   5.1
#
#  [1 rows x 23 columns],
#  'Tim Duncan':    Season   Tm Pos   G    MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2001  SAS  PF  82  3329  27.0  0.576  0.007  0.466  18.0  ...  12.7
#  1    2002  SAS  PF  81  3181  26.9  0.564  0.016  0.455  19.0  ...  12.9
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  29.0  10.7  7.1  17.8  0.257   3.9   3.8  7.6   8.1
#  1  28.0   9.5  6.9  16.5  0.248   3.3   4.2  7.4   7.6
#
#  [2 rows x 23 columns],
#  'Kevin Garnett':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2003  MIN  PF  82  3231.0  29.4  0.547  0.027  0.289  20.1  ...  10.5
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  29.6  10.4  8.0  18.3  0.272   4.9   5.0  9.9   9.8
#
#  [1 rows x 23 columns],
#  'Steve Nash':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2004  PHO  PG  75  2573.0  22.0  0.606  0.254  0.278   5.2  ...  20.3
#  1    2005  PHO  PG  79  2796.0  23.3  0.632  0.324  0.264   6.6  ...  19.0
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  20.5   9.7  1.2  10.9  0.203   4.5  -2.9  1.7   2.4
#  1  23.3  10.3  2.1  12.4  0.212   5.4  -1.6  3.7   4.0
#
#  [2 rows x 23 columns],
#  'Dirk Nowitzki':    Season   Tm Pos   G    MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2006  DAL  PF  78  2820  27.6  0.605  0.129  0.411  14.8  ...   9.5
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  28.9  11.8  4.5  16.3  0.278   5.4   1.3  6.7   6.2
#
#  [1 rows x 23 columns],
#  'Kobe Bryant':    Season   Tm Pos   G    MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2007  LAL  SG  82  3192  24.2  0.576  0.246  0.439   9.0  ...  11.3
#
#     USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  31.4  9.5  4.3  13.8  0.208   5.1   0.3  5.4   6.0
#
#  [1 rows x 23 columns],
#  'LeBron James':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2008  CLE  SF  81  3054.0  31.7  0.591  0.238  0.472  11.9  ...  11.0
#  1    2009  CLE  SF  76  2966.0  31.1  0.604  0.253  0.506  11.1  ...  12.3
#  2    2011  MIA  SF  62  2326.0  30.7  0.605  0.127  0.429  12.6  ...  13.3
#  3    2012  MIA  PF  76  2877.0  31.6  0.640  0.188  0.395  13.1  ...  12.4
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP
#  0  33.8  13.7  6.5  20.3  0.318   9.4   3.6  13.0  11.6
#  1  33.5  13.3  5.2  18.5  0.299   9.7   2.8  12.5  10.9
#  2  32.0  10.0  4.5  14.5  0.298   8.3   2.7  11.0   7.6
#  3  30.2  14.6  4.7  19.3  0.322   9.2   2.4  11.6   9.8
#
#  [4 rows x 23 columns],
#  'Derrick Rose':    Season   Tm Pos   G      MP   PER   TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2010  CHI  PG  81  3026.0  23.5  0.55  0.241  0.348   6.4  ...  13.1
#
#     USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  32.2  8.3  4.8  13.1  0.208   5.8   0.1  5.9   6.0
#
#  [1 rows x 23 columns],
#  'Kevin Durant':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2013  OKC  SF  81  3122.0  29.8  0.635  0.291  0.477  10.8  ...  12.2
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
#  0  33.0  14.8  4.4  19.2  0.295   8.4   0.4  8.8   8.5
#
#  [1 rows x 23 columns],
#  'Stephen Curry':    Season   Tm Pos   G    MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2014  GSW  PG  80  2613  28.0  0.638  0.482  0.251   7.0  ...  14.3
#  1    2015  GSW  PG  79  2700  31.5  0.669  0.554  0.250   8.6  ...  12.9
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP
#  0  28.9  11.5  4.1  15.7  0.288   9.6   0.3   9.9   7.9
#  1  32.6  13.8  4.1  17.9  0.318  12.4   0.1  12.5   9.8
#
#  [2 rows x 23 columns],
#  'Russell Westbrook':    Season   Tm Pos   G    MP   PER    TS%  3PAr    FTr  TRB%  ...  TOV%  USG%  \
#  0    2016  OKC  PG  81  2802  30.6  0.554   0.3  0.433  17.1  ...  15.9  41.7
#
#     OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP
#  0  8.5  4.6  13.1  0.224  10.9   4.7  15.6  12.4
#
#  [1 rows x 23 columns],
#  'James Harden':    Season   Tm Pos   G      MP   PER    TS%   3PAr    FTr  TRB%  ...  TOV%  \
#  0    2017  HOU  SG  72  2551.0  29.8  0.619  0.498  0.502   8.6  ...  15.1
#
#     USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP
#  0  36.1  11.6  3.8  15.4  0.289   9.6   1.3  10.9   8.3
#
#  [1 rows x 23 columns],
#  'Giannis Antetokounmpo':    Season   Tm Pos   G    MP   PER    TS%   3PAr   FTr  TRB%  ...  TOV%  USG%  \
#  0    2018  MIL  PF  72  2358  30.9  0.644  0.163  0.55  19.3  ...  14.8  32.3
#
#     OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP
#  0  8.9  5.5  14.4  0.292   5.7   5.0  10.8   7.6
#
#  [1 rows x 23 columns]}

# %%
team_onoff = {}
for m in mvp:
    n = mvp_names[m]
    team_onoff[n] = {}
    for y in mvp_years[n]:
        team_onoff[n][y] = pd.read_csv('MVP/' + m + '/' + y + '_OnOff[Team].csv')
team_onoff
# Out:
# {'Allen Iverson': {'2000':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.470  30.7  71.9  51.8  57.0   9.4   7.7  16.7  104.1
#   1   On Court  0.461  33.0  74.4  54.0  62.4   8.5   6.6  18.7  100.2
#   2  Off Court  0.009  -2.3  -2.5  -2.2  -5.4   0.9   1.1  -2.0    3.9},
#  'Tim Duncan': {'2001':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.496  26.5  72.1  50.3  56.3   7.9   9.6  15.6  107.2
#   1   On Court  0.471  30.7  70.9  50.4  57.0  10.5   8.6  17.2  102.9
#   2  Off Court  0.025  -4.2   1.2  -0.1  -0.7  -2.6   1.0  -1.6    4.3,
#   '2002':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.502  29.6  71.0  51.6  56.3   8.0   9.8  16.8  107.2
#   1   On Court  0.477  25.7  72.6  49.0  56.2  10.1   7.5  19.5   97.5
#   2  Off Court  0.025   3.9  -1.6   2.6   0.1  -2.1   2.3  -2.7    9.7},
#  'Kevin Garnett': {'2003':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.496  26.8  73.1  51.3  63.0   7.9   8.9  13.5  108.3
#   1   On Court  0.441  26.2  70.1  48.9  58.4   6.6   6.7  17.3   93.8
#   2  Off Court  0.055   0.6   3.0   2.4   4.6   1.3   2.2  -3.8   14.5},
#  'Steve Nash': {'2004':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.555  27.9  67.6  48.7  60.8   7.7   7.1  12.6  120.3
#   1     On-Off  0.494  26.7  69.4  49.3  50.3   6.2   8.4  17.1  102.9
#   2   On Court  0.061   1.2  -1.8  -0.6  10.5   1.5  -1.3  -4.5   17.4,
#   '2005':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.545  22.1  72.4  48.0  64.6   7.1   7.0  13.3  114.2
#   1     On-Off  0.518  22.2  71.2  47.0  61.0   6.4   7.6  14.6  106.2
#   2   On Court  0.027  -0.1   1.2   1.0   3.6   0.7  -0.6  -1.3    8.0},
#  'Dirk Nowitzki': {'2006':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0
        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.559  21.7  79.3  51.3  56.1   9.1   8.6  14.5  118.1
#   1     On-Off  0.536  20.3  81.1  50.1  54.8   8.2   8.2  14.1  110.7
#   2   On Court  0.023   1.4  -1.8   1.2   1.3   0.9   0.4   0.4    7.4},
#  'Giannis Antetokounmpo': {'2018':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.559  20.0  81.1  52.6  59.4   7.5  12.0  13.1  116.6
#   1     On-Off  0.536  21.9  79.2  52.0  61.2   6.9   8.0  13.9  111.5
#   2   On Court  0.023  -1.9   1.9   0.6  -1.8   0.6   4.0  -0.8    5.1}}

# %%
opp_onoff = {}
for m in mvp:
    n = mvp_names[m]
    opp_onoff[n] = {}
    for y in mvp_years[n]:
        opp_onoff[n][y] = pd.read_csv('MVP/' + m + '/' + y + '_OnOff[Opp].csv')
opp_onoff
# Out:
# {'Allen Iverson': {'2000':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  ORtg
#   0     On-Off  0.458  28.1  69.3  48.2  61.1   8.8   7.8  16.8  98.4
#   1   On Court  0.468  25.6  67.0  46.0  63.6   9.5   8.7  16.5  98.6
#   2  Off Court -0.010   2.5   2.3   2.2  -2.5  -0.7  -0.9   0.3  -0.2},
#  'Tim Duncan': {'2001':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.448  27.9  73.5  49.7  53.0   8.5   8.2  15.7   98.5
#   1   On Court  0.477  29.1  69.3  49.6  56.1   8.8   9.1  17.1  103.6
#   2  Off Court -0.029  -1.2   4.2   0.1  -3.1  -0.3  -0.9  -1.4   -5.1,
#   '2002':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.443  29.0  70.4  48.4  54.8   8.6   8.3  16.0   98.1
#   1   On Court  0.494  27.4  74.3  51.0  53.1  10.0   9.0  18.3  103.2
#   2  Off Court -0.051   1.6  -3.9  -2.6   1.7  -1.4  -0.7  -2.3   -5.1},
#  'Kevin Garnett': {'2003':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.441  26.9  73.2  48.7  61.9   7.1   4.8  15.0   98.5
#   1   On Court  0.457  29.9  73.8  51.1  62.9   9.1   7.1  15.2  104.6
#   2  Off Court -0.016  -3.0  -0.6  -2.4  -1.0  -2.0  -2.3  -0.2   -6.1},
#  'Steve Nash': {'2004':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.487  32.4  72.1  51.3  52.9   7.2   6.6  14.9  107.6
#   1     On-Off  0.460  30.6  73.3  50.7  51.2   9.3   7.3  13.0  105.1
#   2   On Court  0.027   1.8  -1.2   0.6   1.7  -2.1  -0.7   1.9    2.5,
#   '2005':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.496  27.6  77.9  52.0  49.1   7.5   5.1  15.9  105.5
#   1     On-Off  0.476  28.8  77.8  53.0  44.4   7.3   6.5  13.9  106.6
#   2   On Court  0.020  -1.2   0.1  -1.0   4.7   0.2  -1.4   2.0   -1.1},
#  'Dirk Nowitzki': {'2006':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.486  24.2  70.6  46.7  53.2   7.3   6.0  15.7  103.9
#   1     On-Off  0.455  27.0  73.0  50.0  51.3   8.6   6.6  17.3  101.7
#   2   On Court  0.031  -2.8  -2.4  -3.3   1.9  -1.3  -0.6  -1.6    2.2},
#  'Kobe Bryant': {'2007':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0
        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.500  18.9  80.0  47.4  60.6   6.1   9.4  13.4  104.5
#   1     On-Off  0.508  20.8  78.1  48.0  62.0   7.3   8.6  12.3  108.2
#   2   On Court -0.008  -1.9   1.9  -0.6  -1.4  -1.2   0.8   1.1   -3.7}}

# %%
diff_onoff = {}
for m in mvp:
    n = mvp_names[m]
    diff_onoff[n] = {}
    for y in mvp_years[n]:
        diff_onoff[n][y] = pd.read_csv('MVP/' + m + '/' + y + '_OnOff[Diff].csv')
diff_onoff
# Out:
# {'Allen Iverson': {'2000':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  ORtg
#   0     On-Off  0.458  28.1  69.3  48.2  61.1   8.8   7.8  16.8  98.4
#   1   On Court  0.468  25.6  67.0  46.0  63.6   9.5   8.7  16.5  98.6
#   2  Off Court -0.010   2.5   2.3   2.2  -2.5  -0.7  -0.9   0.3  -0.2},
#  'Tim Duncan': {'2001':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.448  27.9  73.5  49.7  53.0   8.5   8.2  15.7   98.5
#   1   On Court  0.477  29.1  69.3  49.6  56.1   8.8   9.1  17.1  103.6
#   2  Off Court -0.029  -1.2   4.2   0.1  -3.1  -0.3  -0.9  -1.4   -5.1,
#   '2002':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.443  29.0  70.4  48.4  54.8   8.6   8.3  16.0   98.1
#   1   On Court  0.494  27.4  74.3  51.0  53.1  10.0   9.0  18.3  103.2
#   2  Off Court -0.051   1.6  -3.9  -2.6   1.7  -1.4  -0.7  -2.3   -5.1},
#  'Kevin Garnett': {'2003':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0     On-Off  0.441  26.9  73.2  48.7  61.9   7.1   4.8  15.0   98.5
#   1   On Court  0.457  29.9  73.8  51.1  62.9   9.1   7.1  15.2  104.6
#   2  Off Court -0.016  -3.0  -0.6  -2.4  -1.0  -2.0  -2.3  -0.2   -6.1},
#  'Steve Nash': {'2004':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.487  32.4  72.1  51.3  52.9   7.2   6.6  14.9  107.6
#   1     On-Off  0.460  30.6  73.3  50.7  51.2   9.3   7.3  13.0  105.1
#   2   On Court  0.027   1.8  -1.2   0.6   1.7  -2.1  -0.7   1.9    2.5,
#   '2005':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.496  27.6  77.9  52.0  49.1   7.5   5.1  15.9  105.5
#   1     On-Off  0.476  28.8  77.8  53.0  44.4   7.3   6.5  13.9  106.6
#   2   On Court  0.020  -1.2   0.1  -1.0   4.7   0.2  -1.4   2.0   -1.1},
#  'Dirk Nowitzki': {'2006':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.486  24.2  70.6  46.7  53.2   7.3   6.0  15.7  103.9
#   1     On-Off  0.455  27.0  73.0  50.0  51.3   8.6   6.6  17.3  101.7
#   2   On Court  0.031  -2.8  -2.4  -3.3   1.9  -1.3  -0.6  -1.6    2.2},
#  'Kobe Bryant': {'2007':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0.485  26.4  74.1  49.2  57.4   7.7   7.1  14.7  105.4
#   1     On-Off  0.485  27.6  72.3  49.4  57.1   9.7   8.0  15.3  106.2
#   2   On Court  0.000  -1.2   1.8  -0.2   0.3  -2.0  -0.9  -0.6   -0.8},
#  'LeBron James': {'2008':        Split   eFG%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%   ORtg
#   0  Off Court  0